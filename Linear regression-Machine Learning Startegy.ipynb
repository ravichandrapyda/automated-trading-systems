# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
gross = np.array([5, 10, 17, 27, 35, 40, 42, 49, 54, 60])

# %%
profit = np.array(([2.6, 19. , 23.8, 26.9, 41.1, 58.3, 40.3, 58.7, 73.1, 69.7]))

# %%
df = pd.DataFrame(data = {"gross":gross,"profit":profit})

# %%
df
# Out:
#    gross  profit
# 0      5     2.6
# 1     10    19.0
# 2     17    23.8
# 3     27    26.9
# 4     35    41.1
# 5     40    58.3
# 6     42    40.3
# 7     49    58.7
# 8     54    73.1
# 9     60    69.7

# %%
plt.figure(figsize=(12,8))
plt.scatter(x=df.gross,y=df.profit,s=50)
plt.xlabel("gross",fontsize=13)
plt.ylabel("profit",fontsize=13)
# Out:
# Text(0, 0.5, 'profit')

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression(fit_intercept =True)

# %%
lm.fit(X=df.gross.to_frame(),y=df.profit)
# Out:
# LinearRegression()

# %%
slope = lm.coef_

# %%
intercept = lm.intercept_

# %%
df["prob"] = lm.predict(df.gross.to_frame())
df
# Out:
#    gross  profit       prob
# 0      5     2.6   6.699569
# 1     10    19.0  12.694453
# 2     17    23.8  21.087291
# 3     27    26.9  33.077060
# 4     35    41.1  42.668875
# 5     40    58.3  48.663759
# 6     42    40.3  51.061712
# 7     49    58.7  59.454550
# 8     54    73.1  65.449435
# 9     60    69.7  72.643296

# %%
x_lin = np.array([0,100])
y_lin = intercept+slope * x_lin

# %%
y_lin
# Out:
# array([  0.70468498, 120.60236941])

# %%
plt.figure(figsize = (12,8))
plt.scatter(x=df.gross,y=df.profit,s=50,label = "Data")
plt.plot(x_lin,y_lin,c="red",label = "Regression Line")
plt.xlabel("gross",fontsize=13)
plt.ylabel("profit",fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %% [markdown]
# Makig Predictions Using Linear Regression Model
